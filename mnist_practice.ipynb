# %% [markdown]
# <a href="https://colab.research.google.com/github/MD-330/mnist-cnn-vs-dense/blob/main/mnist_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **dense_model**

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

# %%
def image_normalize(image, label):
  return tf.cast(image, tf.float32) / 255., label

ds_train = ds_train.map(
   image_normalize, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(128)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

# %%
ds_test = ds_test.map(
    image_normalize, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(128)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10)
])
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

history = model.fit(
    ds_train,
    epochs=6,
    validation_data=ds_test,
)
print("\n=== Final Results ===")
print("Train Accuracy:", history.history['sparse_categorical_accuracy'][-1])
print("Validation Accuracy:", history.history['val_sparse_categorical_accuracy'][-1])
print("Train Loss:", history.history['loss'][-1])
print("Validation Loss:", history.history['val_loss'][-1])
# Out:
# Epoch 1/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3622 - sparse_categorical_accuracy: 0.9018 - val_loss: 0.1956 - val_sparse_categorical_accuracy: 0.9439
# Epoch 2/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1684 - sparse_categorical_accuracy: 0.9519 - val_loss: 0.1368 - val_sparse_categorical_accuracy: 0.9589
# Epoch 3/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1207 - sparse_categorical_accuracy: 0.9657 - val_loss: 0.1102 - val_sparse_categorical_accuracy: 0.9676
# Epoch 4/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0922 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1030 - val_sparse_categorical_accuracy: 0.9686
# Epoch 5/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0739 - sparse_categorical_accuracy: 0.9783 - val_loss: 0.0845 - val_sparse_categorical_accuracy: 0.9746
# Epoch 6/6
# ...

# %% [markdown]
# ## **CNN_model**

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/mnist/3.0.1 has no dataset_info.json
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.CYTXD2_3.0.1/mnist-train.tfrecord*...:   0%|          | 0…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.CYTXD2_3.0.1/mnist-test.tfrecord*...:   0%|          | 0/…
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.

# %%
def image_normalize(image, label):
  return tf.cast(image, tf.float32) / 255., label

ds_train = ds_train.map(
   image_normalize, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(128)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

# %%
ds_test = ds_test.map(
    image_normalize, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(128)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
  tf.keras.layers.MaxPooling2D((2,2)),

  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D((2,2)),

  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10)
])
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

history = model.fit(
    ds_train,
    epochs=6,
    validation_data=ds_test,
)
print("\n=== Final Results ===")
print("Train Accuracy:", history.history['sparse_categorical_accuracy'][-1])
print("Validation Accuracy:", history.history['val_sparse_categorical_accuracy'][-1])
print("Train Loss:", history.history['loss'][-1])
print("Validation Loss:", history.history['val_loss'][-1])
# Out:
# Epoch 1/6
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 63s 110ms/step - loss: 0.2084 - sparse_categorical_accuracy: 0.9383 - val_loss: 0.0587 - val_sparse_categorical_accuracy: 0.9800
# Epoch 2/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 50s 107ms/step - loss: 0.0567 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0447 - val_sparse_categorical_accuracy: 0.9849
# ...
